# %%
import pandas as pd

# %%
#Importing dataset for analysis
df= pd.read_csv('zomato.csv')
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 0      942, 21st Main Road, 2nd Stage, Banashankari, ...
# 1      2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...
# 2      1112, Next to KIMS Medical College, 17th Cross...
# ...

# %% [markdown]
# Preliminary overview ( Shape, Head, Tail, Describe, Info)

# %%
df.shape
# Out:
# (51717, 17)

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
df.tail()
# Out:
#                                                      url  \
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                  address  \
# 51712  Four Points by Sheraton Bengaluru, 43/3, White...
# 51713  Number 10, Garudachar Palya, Mahadevapura, Whi...
# 51714  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51715  Sheraton Grand Bengaluru Whitefield Hotel & Co...
# 51716  ITPL Main Road, KIADB Export Promotion Industr...
#
#                                                     name online_order  \
# 51712  Best Brews - Four Points by Sheraton Bengaluru...           No
# 51713                           Vinod Bar And Restaurant           No
# ...

# %%
df.describe()
# Out:
#               votes
# count  51717.000000
# mean     283.697527
# std      803.838853
# min        0.000000
# 25%        7.000000
# 50%       41.000000
# 75%      198.000000
# max    16832.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 17 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   address                      51717 non-null  object
#  2   name                         51717 non-null  object
#  3   online_order                 51717 non-null  object
#  4   book_table                   51717 non-null  object
#  5   rate                         43942 non-null  object
#  6   votes                        51717 non-null  int64
#  7   phone                        50509 non-null  object
#  8   location                     51696 non-null  object
#  9   rest_type                    51490 non-null  object
#  10  dish_liked                   23639 non-null  object
#  11  cuisines                     51672 non-null  object
#  12  approx_cost(for two people)  51371 non-null  object
# ...

# %%
#Checking for null values
df.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
#Drop columns with geographical coordinates
df.drop('listed_in(city)',axis=1,inplace=True)
#Drop locality address and keep only the specific locality name
df.drop('address',axis=1,inplace=True)

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
df.isnull().sum()
# Out:
# url                                0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# dtype: int64

# %%
#Fill missing values
newdf= df.fillna(method='ffill')
newdf
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
newdf.isnull().sum()
# Out:
# url                            0
# name                           0
# online_order                   0
# book_table                     0
# rate                           0
# votes                          0
# phone                          0
# location                       0
# rest_type                      0
# dish_liked                     0
# cuisines                       0
# approx_cost(for two people)    0
# reviews_list                   0
# menu_item                      0
# listed_in(type)                0
# dtype: int64

# %%
#check how many restaurants belong to each price category
price_range = newdf['approx_cost(for two people)'].value_counts()
price_range
# Out:
# 300      7637
# 400      6600
# 500      5013
# 200      4891
# 600      3732
#          ...
# 60          1
# 5,000       1
# 3,700       1
# 469         1
# 160         1
# Name: approx_cost(for two people), Length: 70, dtype: int64

# %%
#plotting above result
import numpy as np
import matplotlib.pyplot as plt
plt.plot(price_range)

# %%
x= newdf['name']
y= newdf['approx_cost(for two people)']

# %%
#check the percent wise distribution of restaurants with each rating category
restaurants_ratings = newdf[['name','rate']]
restaurants_ratings
# Out:
#                                                     name    rate
# 0                                                  Jalsa   4.1/5
# 1                                         Spice Elephant   4.1/5
# 2                                        San Churro Cafe   3.8/5
# 3                                  Addhuri Udupi Bhojana   3.7/5
# 4                                          Grand Village   3.8/5
# ...                                                  ...     ...
# 51712  Best Brews - Four Points by Sheraton Bengaluru...  3.6 /5
# 51713                           Vinod Bar And Restaurant  3.6 /5
# 51714  Plunge - Sheraton Grand Bengaluru Whitefield H...  3.6 /5
# 51715  Chime - Sheraton Grand Bengaluru Whitefield Ho...  4.3 /5
# 51716                       The Nest - The Den Bengaluru  3.4 /5
#
# [51717 rows x 2 columns]

# %%
restaurants_ratings.sort_values('rate')
# Out:
#                                         name rate
# 33444             Sri Annapoorna Andhra Mess    -
# 33409                    Chalo Delhi Darbaar    -
# 33408                            Hit And Run    -
# 33428  When Hunger Strikes, Batman Delivers!    -
# 3373                             Right Pizza    -
# ...                                      ...  ...
# 24529                           Central Cafe  NEW
# 4786                           Chaatora Ghar  NEW
# 24536                         Feel The Taste  NEW
# 4785                           Shree K Foods  NEW
# 13406              Sweet Revenge Bake N Cafe  NEW
#
# [51717 rows x 2 columns]

# %%
#Check rating category with the price range of the restaurant w.r.t Value Counts function
rating_category = newdf[['rate','approx_cost(for two people)']]
rating_category.value_counts()
# Out:
# rate    approx_cost(for two people)
# NEW     300                            670
#         200                            483
# 3.6/5   300                            406
# 3.7/5   400                            382
# 3.3/5   300                            368
#                                       ...
# 4.6 /5  800                              1
# 3.4 /5  1,300                            1
# 3.3/5   850                              1
#         70                               1
# 3.8 /5  2,500                            1
# Length: 1336, dtype: int64

# %%
newdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51717 entries, 0 to 51716
# Data columns (total 15 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   url                          51717 non-null  object
#  1   name                         51717 non-null  object
#  2   online_order                 51717 non-null  object
#  3   book_table                   51717 non-null  object
#  4   rate                         51717 non-null  object
#  5   votes                        51717 non-null  int64
#  6   phone                        51717 non-null  object
#  7   location                     51717 non-null  object
#  8   rest_type                    51717 non-null  object
#  9   dish_liked                   51717 non-null  object
#  10  cuisines                     51717 non-null  object
#  11  approx_cost(for two people)  51717 non-null  object
#  12  reviews_list                 51717 non-null  object
# ...

# %%
#Which localities have the maximum number of very good category restaurants ( TOP 10 )
category = newdf[['location','name','rate']]
localities= category.value_counts()
localities.sort_values(ascending=False).head(10)
# Out:
# location               name                         rate
# Commercial Street      The Chocolate Heaven         NEW       24
# Cunningham Road        Hammered                     4.7/5     18
# Koramangala 4th Block  Cilantro                     4.0 /5    17
#                        Onesta                       4.4 /5    16
# Ulsoor                 Copacabana Pub               NEW       16
# Koramangala 5th Block  The Flying Trapeze           NEW       15
# Bannerghatta Road      Deja Vu Resto Bar            4.4/5     15
# Koramangala 5th Block  Bonsouth                     4.2 /5    14
#                        Over The Top Terrace Lounge  3.9 /5    14
# Koramangala 7th Block  Dipd N Chocolate             NEW       14
# dtype: int64

# %%
# Places with maximum number of restaurants
# Food category Analysis
# Find top 3 most common food category and plot them in pie chart.
# Which localities have the most common category serving restaurants. (Like: North Indian, Chinese etc.)
# Localities serving both north Indian and south Indian food
# Number of restaurants serving only north Indian, Chinese and both together and Visualize them.

# %%
# Find top 3 most common food category and plot them in pie chart.

# %%
# Places with maximum number of restaurants
newdf['name'].value_counts().head(10)
# Out:
# Cafe Coffee Day      96
# Onesta               85
# Just Bake            73
# Empire Restaurant    71
# Five Star Chicken    70
# Kanti Sweets         68
# Petoo                66
# Polar Bear           65
# Baskin Robbins       64
# Chef Baker's         62
# Name: name, dtype: int64

# %%
# Food category Analysis
newdf.dish_liked.info
# Out:
# <bound method Series.info of 0        Pasta, Lunch Buffet, Masala Papad, Paneer Laja...
# 1        Momos, Lunch Buffet, Chocolate Nirvana, Thai G...
# 2        Churros, Cannelloni, Minestrone Soup, Hot Choc...
# 3                                              Masala Dosa
# 4                                      Panipuri, Gol Gappe
#                                ...
# 51712                                 Biryani, Andhra Meal
# 51713                                 Biryani, Andhra Meal
# 51714                                 Biryani, Andhra Meal
# 51715                         Cocktails, Pizza, Buttermilk
# 51716                         Cocktails, Pizza, Buttermilk
# Name: dish_liked, Length: 51717, dtype: object>

# %%
# Find top 3 most common food category and plot them in pie chart.
common = newdf['dish_liked'].value_counts().head(3)
common
# Out:
# Biryani                                                                          456
# Friendly Staff                                                                   344
# Gobhi Pakoda, Bajji, Raita, Ginger Tea, Jalapeno Cheese Poppers, Mojito, Chai    320
# Name: dish_liked, dtype: int64

# %%
# Find top 3 most common food category and plot them in pie chart.
import numpy as np
import matplotlib.pyplot as plt
plt.figure(figsize=(10,8))
plt.pie(common,shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x22719516c10>,
# ...
#  [Text(0.31635929117580025, 1.0535258890443773, ''),
#   Text(-1.0209265158538015, -0.4095229532353689, ''),
#   Text(0.6858387475358712, -0.8600146582346302, '')])

# %%
# Which localities have the most common category serving restaurants. (Like: North Indian, Chinese etc.)
newdf[['location','cuisines']].value_counts()
# Out:
# location            cuisines
# BTM                 North Indian, Chinese                  379
#                     North Indian                           340
# Whitefield          North Indian                           190
# HSR                 North Indian                           173
# Bellandur           North Indian                           161
#                                                           ...
# Lavelle Road        Cafe, Fast Food                          1
#                     Beverages, Desserts, Ice Cream           1
# Kumaraswamy Layout  Street Food                              1
#                     South Indian, Chinese, North Indian      1
# Yeshwantpur         Thai, Chinese, Momos                     1
# Length: 7778, dtype: int64

# %%
# Which localities have the most common category serving restaurants. (Like: North Indian, Chinese etc.)
common_serving = newdf[['location','cuisines']]
common_category= common_serving.groupby('location')
common_category

# %%
common_category
for location,location_common_serving in common_category:
    print(location)
    print(location_common_serving)
# Out:
# BTM
#       location                                           cuisines
# 879        BTM                South Indian, North Indian, Chinese
# 921        BTM                                 Cafe, Healthy Food
# 922        BTM  Healthy Food, North Indian, Biryani, Continent...
# 923        BTM                      Andhra, North Indian, Biryani
# 924        BTM                              Biryani, North Indian
# ...        ...                                                ...
# 42425      BTM                                   Bakery, Desserts
# 42545      BTM                            South Indian, Fast Food
# 45106      BTM                            South Indian, Fast Food
# 47878      BTM                   Asian, Continental, Healthy Food
# 49619      BTM                                Desserts, Ice Cream
#
# [5125 rows x 2 columns]
# Banashankari
#            location                        cuisines
# 0      Banashankari  North Indian, Mughlai, Chinese
# ...

# %%
df
# Out:
#                                                      url  \
# 0      https://www.zomato.com/bangalore/jalsa-banasha...
# 1      https://www.zomato.com/bangalore/spice-elephan...
# 2      https://www.zomato.com/SanchurroBangalore?cont...
# 3      https://www.zomato.com/bangalore/addhuri-udupi...
# 4      https://www.zomato.com/bangalore/grand-village...
# ...                                                  ...
# 51712  https://www.zomato.com/bangalore/best-brews-fo...
# 51713  https://www.zomato.com/bangalore/vinod-bar-and...
# 51714  https://www.zomato.com/bangalore/plunge-sherat...
# 51715  https://www.zomato.com/bangalore/chime-sherato...
# 51716  https://www.zomato.com/bangalore/the-nest-the-...
#
#                                                     name online_order  \
# 0                                                  Jalsa          Yes
# 1                                         Spice Elephant          Yes
# ...

# %%
# Localities serving north Indian food
Locality = df[df['cuisines']== 'North Indian']
Locality.head(3)
# Out:
#                                                   url             name  \
# 5   https://www.zomato.com/bangalore/timepass-dinn...  Timepass Dinner
# 50  https://www.zomato.com/bangalore/petoo-banasha...            Petoo
# 72  https://www.zomato.com/bangalore/spicy-tandoor...    Spicy Tandoor
#
#    online_order book_table   rate  votes                             phone  \
# 5           Yes         No  3.8/5    286  +91 9980040002\r\n+91 9980063005
# 50           No         No  3.7/5     21                    +91 8026893211
# 72           No         No    NEW      0                    +91 8050884222
#
#         location      rest_type  \
# 5   Basavanagudi  Casual Dining
# 50  Banashankari    Quick Bites
# 72  Banashankari    Quick Bites
#
#                                            dish_liked      cuisines  \
# 5   Onion Rings, Pasta, Kadhai Paneer, Salads, Sal...  North Indian
# 50                                                NaN  North Indian
# ...

# %%
# Localities serving south Indian food
South_locality = df[df['cuisines']== 'South Indian']
South_locality
# Out:
#                                                      url  \
# 39     https://www.zomato.com/bangalore/maruthi-davan...
# 41     https://www.zomato.com/bangalore/havyaka-mess-...
# 66     https://www.zomato.com/bangalore/namma-brahmin...
# 76     https://www.zomato.com/bangalore/sri-guru-kott...
# 91     https://www.zomato.com/bangalore/sunsadm-banas...
# ...                                                  ...
# 51570  https://www.zomato.com/bangalore/dharani-andhr...
# 51593  https://www.zomato.com/bangalore/the-south-whi...
# 51609  https://www.zomato.com/bangalore/the-andhra-bh...
# 51624  https://www.zomato.com/bangalore/slv-grand-itp...
# 51642  https://www.zomato.com/bangalore/basaveshwara-...
#
#                                               name online_order book_table  \
# 39                    Maruthi Davangere Benne Dosa          Yes         No
# 41                                    Havyaka Mess           No         No
# ...

# %%
# Number of restaurants serving only north Indian, Chinese and both together and Visualize them.
locality = df[df['cuisines']== 'North Indian, Chinese']
locality
# Out:
#                                                      url  \
# 46     https://www.zomato.com/bangalore/kitchen-garde...
# 63     https://www.zomato.com/bangalore/1947-banashan...
# 83     https://www.zomato.com/bangalore/vaishali-delu...
# 146    https://www.zomato.com/bangalore/darbar-banash...
# 158    https://www.zomato.com/bangalore/the-fortuna-k...
# ...                                                  ...
# 51590  https://www.zomato.com/bangalore/u-p-dhaba-whi...
# 51602  https://www.zomato.com/bangalore/indian-aroma-...
# 51623  https://www.zomato.com/bangalore/paratha-point...
# 51638  https://www.zomato.com/bangalore/party-spice-f...
# 51640  https://www.zomato.com/bangalore/punjabi-charc...
#
#                        name online_order book_table    rate  votes  \
# 46           Kitchen Garden          Yes         No   3.6/5    244
# 63                     1947           No        Yes   4.0/5    808
# 83          Vaishali Deluxe           No         No   3.8/5     42
# ...
